# %% [markdown]
# #3 Word Sentences

# %%
import pickle
import csv
import matplotlib.pyplot as plt

# %%
run 3_word_sentences
# Out:
# 1406228927.71
# 4.34477210045 time to divide into sentences
# 0.455528020859
# 1406228928.17 time to divide into grams
# 4.34486889839 time to generate probability list
# calculating probability of surprise given position
# 1406228934.88
# hello
# calculating probability of surprise given position
# 1406228937.31
# hello
# calculating probability of surprise given position
# 1406228939.72
# hello
# calculating probability of surprise given position
# 1406228942.12
# hello

# %%
# %matplotlib inline

data = list(csv.reader(open("pos_info_3_word_bi.csv","r")))

y_start = data[1]
y_end = data[0]
x = data[2]

plt.figure(1)
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)

plt.figure(2)
p2, = plt.plot(x,y_end)
plt.xlabel("distance from end", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given sentence positons", fontsize = 16)
plt.show()

# %% [markdown]
# n = 2, sentence length = 4

# %%
import numpy
# %matplotlib inline
info_values = data[3]
positions = data[4]
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 245

# %%
# test_data = numpy.zeros([5,3])
# test_data[:,0] = [1, 2, 3, 4, 5]
# test_data[:,1] = [4, 5, 7, 8, 12]
# test_data[:,2] = [0, 4, 5, 6, 7]

# plt.boxplot(test_data)
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python2.7/dist-packages/IPython/kernel/zmq/ipkernel.py", line 389, in execute_request
#     shell.run_cell(code, store_history=store_history, silent=silent)
#
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py", line 2743, in run_cell
#     self.events.trigger('post_execute')
#
#   File "/usr/local/lib/python2.7/dist-packages/IPython/core/events.py", line 82, in trigger
#     func(*args, **kwargs)
#
#   File "/usr/local/lib/python2.7/dist-packages/IPython/kernel/zmq/pylab/backend_inline.py", line 118, in flush_figures
#     return show(True)
#
#   File "/usr/local/lib/python2.7/dist-packages/IPython/kernel/zmq/pylab/backend_inline.py", line 47, in show
#     matplotlib.pyplot.close('all')
#
#   File "/usr/lib/pymodules/python2.7/matplotlib/pyplot.py", line 423, in close
#     _pylab_helpers.Gcf.destroy_all()
#
#   File "/usr/lib/pymodules/python2.7/matplotlib/_pylab_helpers.py", line 86, in destroy_all
#     gc.collect()
#
# KeyboardInterrupt

# %%
info_values = data[3]
#shorten for debugging
#info_values = [info_values[j][:30] for j in range(len(info_values))]

#turn the string '[1, 2, 2.4]' into a list [1, 2, 2.4]
info_values = [re.sub('[\[\]]','', info_values[i]) for i in range(len(info_values))]
temp = []
info_values = [(re.split('\D\s',info_values[k])) for k in range(len(info_values))]
info_values = [[float(info_values[i][j]) for j in range(len(info_values[i]))] for i in range(len(info_values))]

#make plot
plt.boxplot([numpy.matrix(info_values[0]), numpy.matrix(info_values[1]), numpy.matrix(info_values[2])])
plt.xlabel('Position in Sentence',fontsize = 14)
plt.ylabel('Information',fontsize = 14)
plt.title('Range of Information Values at each Position', fontsize=16)
plt.ylim([-1, 10])
# Out:
# (-1, 10)
