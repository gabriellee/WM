# %% [markdown]
# #Unigram Model

# %% [markdown]
# ##3 word sentences

# %%
import pickle
import csv
import matplotlib.pyplot as plt

# %%
run 3_word_sentences
# Out:
# 1406144771.72
# 4.25854301453 time to divide into sentences
# 0.46123790741
# 1406144772.19 time to divide into grams
# 4.25856018066 time to generate probability list
# calculating probability of surprise given position
# 1406144778.88
# calculating probability of surprise given position
# 1406144781.27
# calculating probability of surprise given position
# 1406144783.69

# %%
# %matplotlib inline

data = list(csv.reader(open("pos_info_3_word_sents.csv","r")))

y_start = data[0]
y_end = data[1]
x = data[2]

plt.figure(1)
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)

plt.figure(2)
p2, = plt.plot(x,y_end)
plt.xlabel("distance from end", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given sentence positons", fontsize = 16)
plt.show()

# %% [markdown]
# n = 1, sentence length = 3

# %% [markdown]
# ##4 word sentences

# %%
run 3_word_sentences
# Out:
# 1406145414.72
# 4.18021607399 time to divide into sentences
# 0.462121963501
# 1406145415.19 time to divide into grams
# 4.18023610115 time to generate probability list
# calculating probability of surprise given position
# 1406145421.73
# calculating probability of surprise given position
# 1406145424.13
# calculating probability of surprise given position
# 1406145426.56
# calculating probability of surprise given position
# 1406145428.96

# %%
data = list(csv.reader(open("pos_info_4_word_sents.csv","r")))
print data
y_start = data[0]
y_end = data[1]
x = data[2]

plt.figure(1)
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)

plt.figure(2)
p2, = plt.plot(x,y_end)
plt.xlabel("distance from end", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given sentence positons", fontsize = 16)
plt.show()
