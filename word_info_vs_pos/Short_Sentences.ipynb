# %% [markdown]
# #3 Word Sentences

# %%
import pickle
import csv
import matplotlib.pyplot as plt

# %%
run 3_word_sentences
# Out:
#   File "/home/gabrielle/wkspace/WM/word_info_vs_pos/3_word_sentences", line 228
#     sum_start += -math.log(probs[str(list(n_grams_by_sentences[i][word_pos]))])
#             ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline

data = list(csv.reader(open("pos_info_3_word_sents.csv","r")))

y_start = data[0]
y_end = data[1]
x = data[2]

plt.figure(1)
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)

plt.figure(2)
p2, = plt.plot(x,y_end)
plt.xlabel("distance from end", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.show()
