# %% [markdown]
# #3 Word Sentences

# %%
import pickle
import csv
import matplotlib.pyplot as plt

# %%
run 3_word_sentences
# Out:
# 1406141183.08
# 4.31733703613 time to divide into sentences
# 0.513478040695
# 1406141183.6 time to divide into grams
# 4.31748890877 time to generate probability list
# calculating probability of surprise given position
# 1406141190.49
# calculating probability of surprise given position
# 1406141192.96
# calculating probability of surprise given position
# 1406141195.42

# %%
# %matplotlib inline

data = list(csv.reader(open("pos_info_3_word_sents.csv","r")))

y_start = data[0]
y_end = data[1]
x = data[2]

plt.figure(1)
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)

plt.figure(2)
p2, = plt.plot(x,y_end)
plt.xlabel("distance from end", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given sentence positons", fontsize = 16)
plt.show()

# %% [markdown]
# Why are these two graphs identical? Shouldn't they be mirror images?

# %%
# %matplotlib inline


info_values = data[3]
positions = data[4]

plt.figure(1)
p1, = plt.plot(positions,info_values, '.')
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Information Values of Words in Each Sentence")

plt.show()
