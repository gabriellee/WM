# %% [markdown]
# #3 Word Sentences

# %% [markdown]
# ##unigrams

# %%
import pickle
import csv
import matplotlib.pyplot as plt

# %%
run 3_word_sentences
# Out:
# 5.06853604317 time to divide into sentences
# 1406918004.38 time to divide into grams
# 5.06866288185 time to generate probability list
# 1406918004.38
# 5.11025595665
# 1406918004.44

# %%
# %matplotlib inline

data = list(csv.reader(open("word_info_unigram_10000_3wd.csv","r")))

y_start = data[1]
y_end = data[0]
x = data[2]

plt.figure(1)
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)

plt.figure(2)
p2, = plt.plot(x,y_end)
plt.xlabel("distance from end", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given sentence positons", fontsize = 16)
plt.show()

# %%
import numpy
# %matplotlib inline
info_values = data[3]
positions = data[4]

# %%
info_values = data[3]
#shorten for debugging
#info_values = [info_values[j][:30] for j in range(len(info_values))]

#turn the string '[1, 2, 2.4]' into a list [1, 2, 2.4]
info_values = [re.sub('[\[\]]','', info_values[i]) for i in range(len(info_values))]
temp = []
info_values = [(re.split('\D\s',info_values[k])) for k in range(len(info_values))]
info_values = [[float(info_values[i][j]) for j in range(len(info_values[i]))] for i in range(len(info_values))]

#make plot
plt.boxplot([numpy.matrix(info_values[0]), numpy.matrix(info_values[1]), numpy.matrix(info_values[2])])
plt.xlabel('Position in Sentence',fontsize = 14)
plt.ylabel('Information',fontsize = 14)
plt.title('Range of Information Values at each Position', fontsize=16)
plt.ylim([0, 20])
# Out:
# (0, 20)

# %% [markdown]
# ##bigrams

# %%
import pickle
import csv
import matplotlib.pyplot as plt

# %%
run 3_word_sentences
# Out:
# 5.18407607079 time to divide into sentences
# 1406916927.38 time to divide into grams
# 5.18420100212 time to generate probability list
# 1406916927.38
# 5.71443200111
# 1406916927.88

# %%
# %matplotlib inline

data = list(csv.reader(open("word_info_bigram_10000_3wd.csv","r")))

y_start = data[1]
y_end = data[0]
x = data[2]

plt.figure(1)
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)

plt.figure(2)
p2, = plt.plot(x,y_end)
plt.xlabel("distance from end", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given sentence positons", fontsize = 16)
plt.show()

# %% [markdown]
# n = 2, sentence length = 3

# %%
import numpy
# %matplotlib inline
info_values = data[3]
positions = data[4]

# %%
# test_data = numpy.zeros([5,3])
# test_data[:,0] = [1, 2, 3, 4, 5]
# test_data[:,1] = [4, 5, 7, 8, 12]
# test_data[:,2] = [0, 4, 5, 6, 7]

# plt.boxplot(test_data)

# %%
info_values = data[3]
#shorten for debugging
#info_values = [info_values[j][:30] for j in range(len(info_values))]

#turn the string '[1, 2, 2.4]' into a list [1, 2, 2.4]
info_values = [re.sub('[\[\]]','', info_values[i]) for i in range(len(info_values))]
temp = []
info_values = [(re.split('\D\s',info_values[k])) for k in range(len(info_values))]
info_values = [[float(info_values[i][j]) for j in range(len(info_values[i]))] for i in range(len(info_values))]

#make plot
plt.boxplot([numpy.matrix(info_values[0]), numpy.matrix(info_values[1]), numpy.matrix(info_values[2])])
plt.xlabel('Position in Sentence',fontsize = 14)
plt.ylabel('Information',fontsize = 14)
plt.title('Range of Information Values at each Position', fontsize=16)
plt.ylim([0, 20])
# Out:
# (0, 20)

# %% [markdown]
# ##tri-grams

# %%
run 3_word_sentences
# Out:
# 6.36820697784 time to divide into sentences
# 1406917749.16 time to divide into grams
# 6.36826395988 time to generate probability list
# 1406917749.16
# 7.47982382774
# 1406917751.01

# %%
# %matplotlib inline

data = list(csv.reader(open("word_info_trigram_10000_3wd.csv","r")))

y_start = data[1]
y_end = data[0]
x = data[2]

plt.figure(1)
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)

plt.figure(2)
p2, = plt.plot(x,y_end)
plt.xlabel("distance from end", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given sentence positons", fontsize = 16)
plt.show()

# %%
import numpy
# %matplotlib inline
info_values = data[3]
positions = data[4]

# %%
info_values = data[3]
#shorten for debugging
#info_values = [info_values[j][:30] for j in range(len(info_values))]

#turn the string '[1, 2, 2.4]' into a list [1, 2, 2.4]
info_values = [re.sub('[\[\]]','', info_values[i]) for i in range(len(info_values))]
temp = []
info_values = [(re.split('\D\s',info_values[k])) for k in range(len(info_values))]
info_values = [[float(info_values[i][j]) for j in range(len(info_values[i]))] for i in range(len(info_values))]

#make plot
plt.boxplot([numpy.matrix(info_values[0]), numpy.matrix(info_values[1]), numpy.matrix(info_values[2])])
plt.xlabel('Position in Sentence',fontsize = 14)
plt.ylabel('Information',fontsize = 14)
plt.title('Range of Information Values at each Position', fontsize=16)
plt.ylim([0, 20])
# Out:
# (0, 20)

# %% [markdown]
# #4 Word Sentences

# %% [markdown]
# ##unigram

# %%
run 3_word_sentences
# Out:
# 5.75989508629 time to divide into sentences
# 1406918343.12 time to divide into grams
# 5.75997710228 time to generate probability list
# 1406918343.12
# 5.83010315895
# 1406918343.2
# 5.91199302673

# %%
# %matplotlib inline

data = list(csv.reader(open("word_info_unigram_10000_4wd.csv","r")))

y_start = data[1]
y_end = data[0]
x = data[2]

plt.figure(1)
plt.ylim([0,15])
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)

plt.figure(2)
p2, = plt.plot(x,y_end)
plt.xlabel("distance from end", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given sentence positons", fontsize = 16)
plt.ylim([0,15])

plt.show()

# %%
import numpy
# %matplotlib inline
info_values = data[3]
positions = data[4]

info_values = data[3]
#shorten for debugging
#info_values = [info_values[j][:30] for j in range(len(info_values))]

#turn the string '[1, 2, 2.4]' into a list [1, 2, 2.4]
info_values = [re.sub('[\[\]]','', info_values[i]) for i in range(len(info_values))]
temp = []
info_values = [(re.split('\D\s',info_values[k])) for k in range(len(info_values))]
info_values = [[float(info_values[i][j]) for j in range(len(info_values[i]))] for i in range(len(info_values))]

#make plot
plt.boxplot([numpy.matrix(info_values[0]), numpy.matrix(info_values[1]), numpy.matrix(info_values[2])])
plt.xlabel('Position in Sentence',fontsize = 14)
plt.ylabel('Information',fontsize = 14)
plt.title('Range of Information Values at each Position', fontsize=16)
plt.ylim([0, 20])
# Out:
# (0, 20)

# %% [markdown]
# ##bigram

# %%
run 3_word_sentences
# Out:
# 5.28660702705 time to divide into sentences
# 1406918480.1 time to divide into grams
# 5.28660702705 time to generate probability list
# 1406918480.1
# 5.94514107704
# 1406918480.75
# 6.60771107674

# %%
# %matplotlib inline

data = list(csv.reader(open("word_info_bigram_10000_4wd.csv","r")))

y_start = data[1]
y_end = data[0]
x = data[2]

plt.figure(1)
plt.ylim([0,15])
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)

plt.figure(2)
p2, = plt.plot(x,y_end)
plt.xlabel("distance from end", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given sentence positons", fontsize = 16)
plt.ylim([0,15])

plt.show()

# %% [markdown]
# #5 Word Sentences

# %% [markdown]
# ##bigram

# %%
run 3_word_sentences
# Out:
# 5.25047492981 time to divide into sentences
# 1406918867.05 time to divide into grams
# 5.25053501129 time to generate probability list
# 1406918867.05
# 6.01629900932
# 1406918867.83
# 6.79171705246
# 1406918868.62

# %%
# %matplotlib inline

data = list(csv.reader(open("word_info_bigram_10000_5wd.csv","r")))

y_start = data[1]
y_end = data[0]
x = data[2]

plt.figure(1)
plt.ylim([0,15])
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.title("Average Information Content for given sentence positons", fontsize = 16)
plt.ylabel("information content", fontsize = 14)

plt.figure(2)
p2, = plt.plot(x,y_end)
plt.xlabel("distance from end", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given sentence positons", fontsize = 16)
plt.ylim([0,15])

plt.show()
