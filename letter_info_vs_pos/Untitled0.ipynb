# %% [markdown]
# #Letter information versus Position

# %%
import pickle
import csv
import matplotlib.pyplot as plt

# %%
run letter_info.py
# Out:
# 1406233878.09
# 4.68846297264 time to divide into sentences
# 2.47112488747
# 1406233880.57 time to divide into grams
# 4.68850803375 time to generate probability list
# calculating probability of surprise given position
# 1406233885.52
# 0 10000 ['f', 'r', 'e', 's', 'h'] 10000
# [['f'], ('f', 'r'), ('r', 'e'), ('e', 's'), ('s', 'h')]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/gabrielle/wkspace/WM/letter_info_vs_pos/letter_info.py in <module>()
#     202
#     203
# --> 204 main(2)
#
# /home/gabrielle/wkspace/WM/letter_info_vs_pos/letter_info.py in main(n)
#      73         #pdb.set_trace()
#      74         for letter_pos in range(maxm):
# ---> 75                 avg_info_start, avg_info_end, all_probs, info_values, pos_list = calc_avg_surprise(n, all_words, letter_pos, n_grams_by_words, n_gram_list, all_probs, all_letters)
#      76                 y_start.append(avg_info_start)
#      77                 y_end.append(avg_info_end)
#
# /home/gabrielle/wkspace/WM/letter_info_vs_pos/letter_info.py in calc_avg_surprise(n, all_words, letter_pos, n_grams_by_words, n_gram_list, probs, all_letters)
#     187
#     188                         if str(list(n_grams_by_words[i][-letter_pos])) in probs:
# --> 189                                 sum_end += -math.log(probs[str(n_grams_by_words[i][-letter_pos - 1])])
#     190                                 count_end += 1
#     191                         else:
#
# KeyError: "('s', 'h')"

# %%
# %matplotlib inline

data = list(csv.reader(open("pos_info_letters.csv","r")))
#print data
y_start = data[0]
y_end = data[1]
x = data[2]

plt.figure(1)
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)


plt.figure(2)
p2, = plt.plot(x,y_end)
plt.xlabel("distance from end", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given sentence positons", fontsize = 16)
plt.show()

# %%
plt.show()
