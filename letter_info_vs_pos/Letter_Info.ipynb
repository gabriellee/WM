# %% [markdown]
# #3 Letter Words

# %% [markdown]
# ##unigram

# %%
import pickle
import csv
import matplotlib.pyplot as plt

# %%
run letter_info.py
# Out:
# 1406919985.42
# 5.78075790405 time to divide into sentences
# 2.79279589653
# 1406919988.22 time to divide into grams
# 5.78088092804 time to generate probability list
# calculating probability of surprise given position
# 1406919994.13
# calculating probability of surprise given position
# 1406919994.38
# calculating probability of surprise given position
# 1406919994.63

# %%
# %matplotlib inline

data = list(csv.reader(open("letter_info_unigram_10000_3ltr.csv","r")))

y_start = data[1]
y_end = data[0]
x = data[2]

plt.figure(1)
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given word positions", fontsize = 16)

# plt.figure(2)
# p2, = plt.plot(x,y_end)
# plt.xlabel("distance from end", fontsize = 14)
# plt.ylabel("information content", fontsize = 14)
# plt.title("Average Information Content for given sentence positons", fontsize = 16)
# plt.show()

# %%
import numpy
# %matplotlib inline
info_values = data[3]
positions = data[4]

#shorten for debugging
#info_values = [info_values[j][:30] for j in range(len(info_values))]

#turn the string '[1, 2, 2.4]' into a list [1, 2, 2.4]
info_values = [re.sub('[\[\]]','', info_values[i]) for i in range(len(info_values))]
temp = []
info_values = [(re.split('\D\s',info_values[k])) for k in range(len(info_values))]
info_values = [[float(info_values[i][j]) for j in range(len(info_values[i]))] for i in range(len(info_values))]

#make plot
plt.boxplot([numpy.matrix(info_values[0]), numpy.matrix(info_values[1]), numpy.matrix(info_values[2])])
plt.xlabel('Position in Sentence',fontsize = 14)
plt.ylabel('Information',fontsize = 14)
plt.title('Range of Information Values at each Position', fontsize=16)

# %% [markdown]
# ##bigram

# %% [markdown]
# #4 Letter Words

# %% [markdown]
# ##unigram

# %%
run letter_info.py
# Out:
# 1406921183.24
# 7.07787513733 time to divide into sentences
# 4.32932305336
# 1406921187.58 time to divide into grams
# 7.07792615891 time to generate probability list
# calculating probability of surprise given position
# 1406921194.95
# calculating probability of surprise given position
# 1406921195.23
# calculating probability of surprise given position
# 1406921195.51
# calculating probability of surprise given position
# 1406921196.02

# %%
# %matplotlib inline

data = list(csv.reader(open("letter_info_unigram_10000_4ltr.csv","r")))

y_start = data[1]
y_end = data[0]
x = data[2]

plt.figure(1)
p1, = plt.plot(x,y_start)
plt.title("Average Information Content for given word positions", fontsize = 16)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)

# plt.figure(2)
# p2, = plt.plot(x,y_end)
# plt.xlabel("distance from end", fontsize = 14)
# plt.ylabel("information content", fontsize = 14)
# plt.title("Average Information Content for given sentence positons", fontsize = 16)
# plt.show()

# %%
import numpy
# %matplotlib inline
info_values = data[3]
positions = data[4]

#shorten for debugging
#info_values = [info_values[j][:30] for j in range(len(info_values))]

#turn the string '[1, 2, 2.4]' into a list [1, 2, 2.4]
info_values = [re.sub('[\[\]]','', info_values[i]) for i in range(len(info_values))]
temp = []
info_values = [(re.split('\D\s',info_values[k])) for k in range(len(info_values))]
info_values = [[float(info_values[i][j]) for j in range(len(info_values[i]))] for i in range(len(info_values))]

#make plot
plt.boxplot([numpy.matrix(info_values[0]), numpy.matrix(info_values[1]), numpy.matrix(info_values[2])])
plt.xlabel('Position in Sentence',fontsize = 14)
plt.ylabel('Information',fontsize = 14)
plt.title('Range of Information Values at each Position', fontsize=16)

# %% [markdown]
# ##bigram

# %%
run letter_info.py
# Out:
# 1406921515.88
# 5.85978603363 time to divide into sentences
# 5.75296497345
# 1406921521.64 time to divide into grams
# 5.85982108116 time to generate probability list
# calculating probability of surprise given position
# 1406921533.71
# calculating probability of surprise given position
# 1406921540.07
# calculating probability of surprise given position
# 1406921546.4
# calculating probability of surprise given position
# 1406921553.04

# %%
# %matplotlib inline

data = list(csv.reader(open("letter_info_bigram_20000_4ltr.csv","r")))

y_start = data[1]
y_end = data[0]
x = data[2]

plt.figure(1)
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)

plt.figure(2)
p2, = plt.plot(x,y_end)
plt.xlabel("distance from end", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given sentence positons", fontsize = 16)
plt.show()

# %%
import numpy
# %matplotlib inline
info_values = data[3]
positions = data[4]

#shorten for debugging
#info_values = [info_values[j][:30] for j in range(len(info_values))]

#turn the string '[1, 2, 2.4]' into a list [1, 2, 2.4]
info_values = [re.sub('[\[\]]','', info_values[i]) for i in range(len(info_values))]
temp = []
info_values = [(re.split('\D\s',info_values[k])) for k in range(len(info_values))]
info_values = [[float(info_values[i][j]) for j in range(len(info_values[i]))] for i in range(len(info_values))]

#make plot
plt.boxplot([numpy.matrix(info_values[0]), numpy.matrix(info_values[1]), numpy.matrix(info_values[2])])
plt.xlabel('Position in Sentence',fontsize = 14)
plt.ylabel('Information',fontsize = 14)
plt.title('Range of Information Values at each Position', fontsize=16)

# %% [markdown]
# ##trigram

# %% [markdown]
# #5 Letter Words

# %% [markdown]
# ##unigram

# %% [markdown]
# ##bigram

# %%
run letter_info.py
# Out:
# 1406921672.26
# 5.64040398598 time to divide into sentences
# 6.37992405891
# 1406921678.65 time to divide into grams
# 5.64044690132 time to generate probability list
# calculating probability of surprise given position
# 1406921691.28
# calculating probability of surprise given position
# 1406921698.62
# calculating probability of surprise given position
# 1406921705.57
# calculating probability of surprise given position
# 1406921712.39
# calculating probability of surprise given position
# 1406921719.28

# %%
# %matplotlib inline

data = list(csv.reader(open("letter_info_bigram_20000_5ltr.csv","r")))

y_start = data[1]
y_end = data[0]
x = data[2]

plt.figure(1)
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)

plt.figure(2)
p2, = plt.plot(x,y_end)
plt.xlabel("distance from end", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given sentence positons", fontsize = 16)
plt.show()

# %%
import numpy
# %matplotlib inline
info_values = data[3]
positions = data[4]

#shorten for debugging
#info_values = [info_values[j][:30] for j in range(len(info_values))]

#turn the string '[1, 2, 2.4]' into a list [1, 2, 2.4]
info_values = [re.sub('[\[\]]','', info_values[i]) for i in range(len(info_values))]
temp = []
info_values = [(re.split('\D\s',info_values[k])) for k in range(len(info_values))]
info_values = [[float(info_values[i][j]) for j in range(len(info_values[i]))] for i in range(len(info_values))]

#make plot
plt.boxplot([numpy.matrix(info_values[0]), numpy.matrix(info_values[1]), numpy.matrix(info_values[2])])
plt.xlabel('Position in Sentence',fontsize = 14)
plt.ylabel('Information',fontsize = 14)
plt.title('Range of Information Values at each Position', fontsize=16)

# %% [markdown]
# ##trigram

# %% [markdown]
# #9 Letter Words

# %% [markdown]
# ##unigram

# %%
run letter_info.py
# Out:
# 1406924027.67
# 6.68038392067 time to divide into sentences
# 10.2293071747
# 1406924037.92 time to divide into grams
# 6.68043684959 time to generate probability list
# calculating probability of surprise given position
# 1406924045.38
# calculating probability of surprise given position
# 1406924046.32
# calculating probability of surprise given position
# 1406924047.29
# calculating probability of surprise given position
# 1406924048.25
# calculating probability of surprise given position
# 1406924049.17
# calculating probability of surprise given position
# 1406924050.09
# calculating probability of surprise given position
# 1406924051.02
# calculating probability of surprise given position
# 1406924051.96
# calculating probability of surprise given position
# 1406924052.87

# %%
# %matplotlib inline

data = list(csv.reader(open("letter_info_unigram_20000_9ltr.csv","r")))

y_start = data[1]
y_end = data[0]
x = data[2]

plt.figure(1)
p1, = plt.plot(x,y_start)
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)

# plt.figure(2)
# p2, = plt.plot(x,y_end)
# plt.xlabel("distance from end", fontsize = 14)
# plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given word positons", fontsize = 16)
plt.show()

# %% [markdown]
# ##bigram

# %%
run letter_info.py
# Out:
# 1406923432.33
# 6.89904904366 time to divide into sentences
# 8.01519203186
# 1406923440.37 time to divide into grams
# 6.89912605286 time to generate probability list
# calculating probability of surprise given position
# 1406923456.81
# calculating probability of surprise given position
# 1406923467.54
# calculating probability of surprise given position
# 1406923478.98
# calculating probability of surprise given position
# 1406923490.55
# calculating probability of surprise given position
# 1406923500.75
# calculating probability of surprise given position
# 1406923510.4
# calculating probability of surprise given position
# 1406923522.78
# calculating probability of surprise given position
# 1406923532.49
# calculating probability of surprise given position
# 1406923542.48

# %%
# %matplotlib inline

data = list(csv.reader(open("letter_info_bigram_20000_9ltr.csv","r")))

y_start = data[1]
y_end = data[0]
x = data[2]

plt.figure(1)
p1, = plt.plot(x[1:],y_start[1:])
plt.xlabel("distance from start", fontsize = 14)
plt.ylabel("information content", fontsize = 14)
plt.title("Average Information Content for given word positons", fontsize = 16)


# plt.figure(2)
# p2, = plt.plot(x[:-2],y_end[:-2])
# plt.xlabel("distance from end", fontsize = 14)
# plt.ylabel("information content", fontsize = 14)
# plt.title("Average Information Content for given sentence positons", fontsize = 16)
# plt.show()

# %% [markdown]
# ##trigram
